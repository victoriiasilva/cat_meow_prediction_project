# %%
import os
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
# !pwd
# Out:
# /home/fll_data_bata/code/Franloplam

# %%
cats_db = os.path.join(os.getcwd(),"DB Gatos")
cats_db
# Out:
# '/home/fll_data_bata/code/Franloplam/DB Gatos'

# %%
dataset_path = os.path.join(cats_db,"dataset","dataset")
dataset_path
# Out:
# '/home/fll_data_bata/code/Franloplam/DB Gatos/dataset/dataset'

# %%
os.listdir(dataset_path)
# Out:
# ['F_MAT01_EU_FN_RIT01_301.wav',
#  'I_BLE01_EU_FN_DEL01_207.wav',
#  'F_IND01_EU_FN_ELI01_203.wav',
#  'I_MEG01_MC_FI_SIM01_104.wav',
#  'F_IND01_EU_FN_ELI01_301.wav',
#  'I_SPI01_EU_MN_NAI01_302.wav',
#  'I_BRA01_MC_MN_SIM01_102.wav',
#  'I_MAT01_EU_FN_RIT01_201.wav',
#  'F_BRI01_MC_FI_SIM01_201.wav',
#  'B_MAT01_EU_FN_RIT01_206.wav',
#  'F_SPI01_EU_MN_NAI01_103.wav',
#  'I_NUL01_MC_MI_SIM01_101.wav',
#  'I_BLE01_EU_FN_DEL01_209.wav',
#  'I_MAT01_EU_FN_RIT01_210.wav',
#  'F_BRA01_MC_MN_SIM01_302.wav',
#  'I_WHO01_MC_FI_SIM01_110.wav',
#  'I_CAN01_EU_FN_GIA01_211.wav',
#  'F_WHO01_MC_FI_SIM01_306.wav',
#  'I_DAK01_MC_FN_SIM01_309.wav',
#  'I_WHO01_MC_FI_SIM01_105.wav',
#  'I_WHO01_MC_FI_SIM01_109.wav',
#  'B_MAT01_EU_FN_RIT01_301.wav',
#  'I_BAC01_MC_MN_SIM01_103.wav',
#  'I_BRA01_MC_MN_SIM01_104.wav',
#  'B_CAN01_EU_FN_GIA01_301.wav',
#  'I_SPI01_EU_MN_NAI01_304.wav',
#  'F_BAC01_MC_MN_SIM01_101.wav',
#  'I_BAC01_MC_MN_SIM01_302.wav',
#  'I_MAT01_EU_FN_RIT01_207.wav',
#  'B_JJX01_MC_FN_SIM01_102.wav',
#  'B_JJX01_MC_FN_SIM01_301.wav',
#  'B_ANI01_MC_FN_SIM01_303.wav',
#  'B_CAN01_EU_FN_GIA01_207.wav',
#  'I_CAN01_EU_FN_GIA01_301.wav',
#  'I_DAK01_MC_FN_SIM01_108.wav',
#  'I_MIN01_EU_FN_BEN01_104.wav',
#  'F_IND01_EU_FN_ELI01_201.wav',
#  'I_NUL01_MC_MI_SIM01_205.wav',
#  'B_BRA01_MC_MN_SIM01_301.wav',
#  'B_JJX01_MC_FN_SIM01_103.wav',
#  'B_SPI01_EU_MN_NAI01_103.wav',
#  'B_NUL01_MC_MI_SIM01_201.wav',
#  'B_BAC01_MC_MN_SIM01_101.wav',
#  'I_DAK01_MC_FN_SIM01_307.wav',
#  'I_CLE01_EU_FN_FER01_116.wav',
#  'I_MAG01_EU_FN_FED01_101.wav',
#  'B_JJX01_MC_FN_SIM01_302.wav',
#  'I_CLE01_EU_FN_FER01_101.wav',
#  'F_CAN01_EU_FN_GIA01_201.wav',
#  'F_MAG01_EU_FN_FED01_101.wav',
#  'B_CAN01_EU_FN_GIA01_105.wav',
#  'I_SPI01_EU_MN_NAI01_201.wav',
#  'B_DAK01_MC_FN_SIM01_301.wav',
#  'I_CLE01_EU_FN_FER01_117.wav',
#  'F_BLE01_EU_FN_DEL01_101.wav',
#  'I_CAN01_EU_FN_GIA01_207.wav',
#  'F_MAG01_EU_FN_FED01_203.wav',
#  'I_MEG01_MC_FI_SIM01_306.wav',
#  'B_IND01_EU_FN_ELI01_305.wav',
#  'I_BLE01_EU_FN_DEL01_102.wav',
#  'B_MAG01_EU_FN_FED01_205.wav',
#  'I_BRA01_MC_MN_SIM01_305.wav',
#  'I_BRA01_MC_MN_SIM01_306.wav',
#  'F_DAK01_MC_FN_SIM01_301.wav',
#  'I_MEG01_MC_FI_SIM01_303.wav',
#  'I_CAN01_EU_FN_GIA01_302.wav',
#  'I_CLE01_EU_FN_FER01_118.wav',
#  'B_MIN01_EU_FN_BEN01_103.wav',
#  'I_BRA01_MC_MN_SIM01_304.wav',
#  'B_MAT01_EU_FN_RIT01_204.wav',
#  'B_MAT01_EU_FN_RIT01_201.wav',
#  'B_WHO01_MC_FI_SIM01_202.wav',
#  'I_NUL01_MC_MI_SIM01_204.wav',
#  'I_DAK01_MC_FN_SIM01_104.wav',
#  'I_CAN01_EU_FN_GIA01_307.wav',
#  'B_MAT01_EU_FN_RIT01_102.wav',
#  'I_BLE01_EU_FN_DEL01_211.wav',
#  'I_WHO01_MC_FI_SIM01_103.wav',
#  'F_LEO01_EU_MI_RIT01_105.wav',
#  'B_SPI01_EU_MN_NAI01_101.wav',
#  'F_WHO01_MC_FI_SIM01_307.wav',
#  'B_BAC01_MC_MN_SIM01_303.wav',
#  'I_SPI01_EU_MN_NAI01_204.wav',
#  'I_CLE01_EU_FN_FER01_119.wav',
#  'I_SPI01_EU_MN_NAI01_205.wav',
#  'B_WHO01_MC_FI_SIM01_101.wav',
#  'I_MAG01_EU_FN_FED01_202.wav',
#  'F_MEG01_MC_FI_SIM01_303.wav',
#  'I_BAC01_MC_MN_SIM10_102.wav',
#  'B_IND01_EU_FN_ELI01_102.wav',
#  'B_WHO01_MC_FI_SIM01_203.wav',
#  'I_WHO01_MC_FI_SIM01_114.wav',
#  'I_DAK01_MC_FN_SIM01_113.wav',
#  'F_SPI01_EU_MN_NAI01_203.wav',
#  'B_ANI01_MC_FN_SIM01_103.wav',
#  'I_BLE01_EU_FN_DEL01_109.wav',
#  'B_BRI01_MC_FI_SIM01_201.wav',
#  'I_WHO01_MC_FI_SIM01_113.wav',
#  'I_DAK01_MC_FN_SIM01_110.wav',
#  'B_WHO01_MC_FI_SIM01_304.wav',
#  'F_MAG01_EU_FN_FED01_303.wav',
#  'B_NIG01_MC_MN_SIM01_101.wav',
#  'I_MAT01_EU_FN_RIT01_204.wav',
#  'F_WHO01_MC_FI_SIM01_304.wav',
#  'F_MIN01_EU_FN_BEN01_103.wav',
#  'F_MAG01_EU_FN_FED01_302.wav',
#  'B_IND01_EU_FN_ELI01_101.wav',
#  'F_MAG01_EU_FN_FED01_201.wav',
#  'F_WHO01_MC_FI_SIM01_101.wav',
#  'B_CAN01_EU_FN_GIA01_208.wav',
#  'I_MEG01_MC_FI_SIM01_103.wav',
#  'I_BLE01_EU_FN_DEL01_217.wav',
#  'B_IND01_EU_FN_ELI01_103.wav',
#  'I_DAK01_MC_FN_SIM01_105.wav',
#  'I_BRA01_MC_MN_SIM01_301.wav',
#  'B_MAG01_EU_FN_FED01_302.wav',
#  'F_BRI01_MC_FI_SIM01_106.wav',
#  'I_SPI01_EU_MN_NAI01_203.wav',
#  'I_BLE01_EU_FN_DEL01_302.wav',
#  'I_BAC01_MC_MN_SIM01_101.wav',
#  'F_DAK01_MC_FN_SIM01_302.wav',
#  'B_WHO01_MC_FI_SIM01_104.wav',
#  'I_WHO01_MC_FI_SIM01_106.wav',
#  'I_MIN01_EU_FN_BEN01_101.wav',
#  'I_CAN01_EU_FN_GIA01_206.wav',
#  'I_BLE01_EU_FN_DEL01_215.wav',
#  'B_MAT01_EU_FN_RIT01_101.wav',
#  'I_NUL01_MC_MI_SIM01_302.wav',
#  'B_MAG01_EU_FN_FED01_103.wav',
#  'B_CAN01_EU_FN_GIA01_201.wav',
#  'F_MAG01_EU_FN_FED01_104.wav',
#  'I_MAT01_EU_FN_RIT01_206.wav',
#  'F_BAC01_MC_MN_SIM01_102.wav',
#  'F_SPI01_EU_MN_NAI01_202.wav',
#  'I_CAN01_EU_FN_GIA01_104.wav',
#  'I_BLE01_EU_FN_DEL01_206.wav',
#  'I_CAN01_EU_FN_GIA01_303.wav',
#  'I_BLE01_EU_FN_DEL01_108.wav',
#  'B_CAN01_EU_FN_GIA01_305.wav',
#  'I_BLE01_EU_FN_DEL01_310.wav',
#  'B_WHO01_MC_FI_SIM01_301.wav',
#  'I_BLE01_EU_FN_DEL01_107.wav',
#  'I_BLE01_EU_FN_DEL01_203.wav',
#  'F_IND01_EU_FN_ELI01_101.wav',
#  'I_WHO01_MC_FI_SIM01_107.wav',
#  'B_WHO01_MC_FI_SIM01_305.wav',
#  'B_SPI01_EU_MN_NAI01_301.wav',
#  'F_SPI01_EU_MN_NAI01_101.wav',
#  'I_CAN01_EU_FN_GIA01_212.wav',
#  'B_WHO01_MC_FI_SIM01_201.wav',
#  'F_BAC01_MC_MN_SIM01_105.wav',
#  'B_IND01_EU_FN_ELI01_301.wav',
#  'I_MIN01_EU_FN_BEN01_103.wav',
#  'I_TIG01_EU_FN_GIU01_201.wav',
#  'B_REG01_EU_FN_GIO01_102.wav',
#  'I_BLE01_EU_FN_DEL01_104.wav',
#  'I_ANI01_MC_FN_SIM01_103.wav',
#  'B_JJX01_MC_FN_SIM01_202.wav',
#  'B_CAN01_EU_FN_GIA01_306.wav',
#  'I_TIG01_EU_FN_GIU01_202.wav',
#  'B_MAG01_EU_FN_FED01_201.wav',
#  'I_MEG01_MC_FI_SIM01_102.wav',
#  'F_MAG01_EU_FN_FED01_301.wav',
#  'F_LEO01_EU_MI_RIT01_103.wav',
#  'F_IND01_EU_FN_ELI01_103.wav',
#  'I_SPI01_EU_MN_NAI01_301.wav',
#  'B_MAG01_EU_FN_FED01_301.wav',
#  'B_IND01_EU_FN_ELI01_201.wav',
#  'I_WHO01_MC_FI_SIM01_102.wav',
#  'B_IND01_EU_FN_ELI01_304.wav',
#  'I_BLE01_EU_FN_DEL01_303.wav',
#  'F_REG01_EU_FN_GIO01_201.wav',
#  'I_DAK01_MC_FN_SIM01_101.wav',
#  'I_BLE01_EU_FN_DEL01_204.wav',
#  'I_BLE01_EU_FN_DEL01_301.wav',
#  'F_WHO01_MC_FI_SIM01_302.wav',
#  'I_BAC01_MC_MN_SIM01_301.wav',
#  'B_NUL01_MC_MI_SIM01_102.wav',
#  'F_MAG01_EU_FN_FED01_103.wav',
#  'I_CLE01_EU_FN_FER01_121.wav',
#  'B_CAN01_EU_FN_GIA01_103.wav',
#  'I_MEG01_MC_FI_SIM01_305.wav',
#  'I_CAN01_EU_FN_GIA01_101.wav',
#  'B_CAN01_EU_FN_GIA01_102.wav',
#  'B_MAG01_EU_FN_FED01_101.wav',
#  'I_CAN01_EU_FN_GIA01_203.wav',
#  'B_MIN01_EU_FN_BEN01_102.wav',
#  'I_CAN01_EU_FN_GIA01_102.wav',
#  'F_MIN01_EU_FN_BEN01_101.wav',
#  'F_MAG01_EU_FN_FED01_102.wav',
#  'B_NIG01_MC_MN_SIM01_201.wav',
#  'I_DAK01_MC_FN_SIM01_305.wav',
#  'I_DAK01_MC_FN_SIM01_311.wav',
#  'B_BRI01_MC_FI_SIM01_301.wav',
#  'I_ANI01_MC_FN_SIM01_104.wav',
#  'F_MEG01_MC_FI_SIM01_304.wav',
#  'I_CAN01_EU_FN_GIA01_204.wav',
#  'F_BRI01_MC_FI_SIM01_103.wav',
#  'F_IND01_EU_FN_ELI01_104.wav',
#  'I_BLE01_EU_FN_DEL01_402.wav',
#  'I_ANI01_MC_FN_SIM01_101.wav',
#  'B_BRA01_MC_MN_SIM01_101.wav',
#  'F_MAT01_EU_FN_RIT01_303.wav',
#  'F_BAC01_MC_MN_SIM01_301.wav',
#  'F_MAT01_EU_FN_RIT01_101.wav',
#  'B_MIN01_EU_FN_BEN01_101.wav',
#  'B_BRA01_MC_MN_SIM01_302.wav',
#  'I_MAT01_EU_FN_RIT01_208.wav',
#  'I_DAK01_MC_FN_SIM01_310.wav',
#  'I_BLE01_EU_FN_DEL01_213.wav',
#  'I_BLE01_EU_FN_DEL01_212.wav',
#  'I_BLE01_EU_FN_DEL01_311.wav',
#  'I_BRA01_MC_MN_SIM01_303.wav',
#  'B_DAK01_MC_FN_SIM01_102.wav',
#  'F_BAC01_MC_MN_SIM01_203.wav',
#  'B_BRA01_MC_MN_SIM01_104.wav',
#  'B_WHO01_MC_FI_SIM01_302.wav',
#  'B_BRI01_MC_FI_SIM01_102.wav',
#  'B_WHO01_MC_FI_SIM01_204.wav',
#  'B_JJX01_MC_FN_SIM01_201.wav',
#  'I_BLE01_EU_FN_DEL01_403.wav',
#  'I_BRA01_MC_MN_SIM01_103.wav',
#  'B_ANI01_MC_FN_SIM01_301.wav',
#  'F_IND01_EU_FN_ELI01_302.wav',
#  'F_BAC01_MC_MN_SIM01_304.wav',
#  'B_BRI01_MC_FI_SIM01_202.wav',
#  'I_CLE01_EU_FN_FER01_107.wav',
#  'I_WHO01_MC_FI_SIM01_101.wav',
#  'I_CLE01_EU_FN_FER01_104.wav',
#  'F_LEO01_EU_MI_RIT01_104.wav',
#  'B_MAG01_EU_FN_FED01_102.wav',
#  'F_WHO01_MC_FI_SIM01_102.wav',
#  'I_CLE01_EU_FN_FER01_103.wav',
#  'B_IND01_EU_FN_ELI01_203.wav',
#  'I_BLE01_EU_FN_DEL01_208.wav',
#  'F_MIN01_EU_FN_BEN01_102.wav',
#  'B_REG01_EU_FN_GIO01_201.wav',
#  'F_LEO01_EU_MI_RIT01_101.wav',
#  'F_BAC01_MC_MN_SIM01_103.wav',
#  'F_SPI01_EU_MN_NAI01_301.wav',
#  'I_TIG01_EU_FN_GIU01_203.wav',
#  'B_MAG01_EU_FN_FED01_204.wav',
#  'B_NIG01_MC_MN_SIM01_103.wav',
#  'I_WHO01_MC_FI_SIM01_201.wav',
#  'I_WHO01_MC_FI_SIM01_301.wav',
#  'B_BRI01_MC_FI_SIM01_303.wav',
#  'B_CAN01_EU_FN_GIA01_204.wav',
#  'B_CAN01_EU_FN_GIA01_202.wav',
#  'I_DAK01_MC_FN_SIM01_312.wav',
#  'I_DAK01_MC_FN_SIM01_115.wav',
#  'F_MAT01_EU_FN_RIT01_103.wav',
#  'I_CAN01_EU_FN_GIA01_306.wav',
#  'B_IND01_EU_FN_ELI01_302.wav',
#  'I_DAK01_MC_FN_SIM01_114.wav',
#  'F_BRI01_MC_FI_SIM01_101.wav',
#  'B_WHO01_MC_FI_SIM01_103.wav',
#  'F_MAT01_EU_FN_RIT01_102.wav',
#  'F_CAN01_EU_FN_GIA01_202.wav',
#  'B_CAN01_EU_FN_GIA01_303.wav',
#  'I_BLE01_EU_FN_DEL01_106.wav',
#  'F_IND01_EU_FN_ELI01_304.wav',
#  'I_DAK01_MC_FN_SIM01_315.wav',
#  'I_BLE01_EU_FN_DEL01_205.wav',
#  'I_CAN01_EU_FN_GIA01_208.wav',
#  'B_JJX01_MC_FN_SIM01_101.wav',
#  'I_CLE01_EU_FN_FER01_114.wav',
#  'I_NUL01_MC_MI_SIM01_303.wav',
#  'I_BRA01_MC_MN_SIM01_302.wav',
#  'I_MEG01_MC_FI_SIM01_304.wav',
#  'I_MEG01_MC_FI_SIM01_301.wav',
#  'F_BLE01_EU_FN_DEL01_103.wav',
#  'I_CAN01_EU_FN_GIA01_209.wav',
#  'B_MIN01_EU_FN_BEN01_104.wav',
#  'I_WHO01_MC_FI_SIM01_116.wav',
#  'I_BLE01_EU_FN_DEL01_219.wav',
#  'I_CAN01_EU_FN_GIA01_305.wav',
#  'F_BLE01_EU_FN_DEL01_102.wav',
#  'I_BLE01_EU_FN_DEL01_103.wav',
#  'B_MAT01_EU_FN_RIT01_207.wav',
#  'F_MAG01_EU_FN_FED01_105.wav',
#  'F_MAG01_EU_FN_FED01_304.wav',
#  'I_CAN01_EU_FN_GIA01_205.wav',
#  'I_DAK01_MC_FN_SIM01_302.wav',
#  'I_MAG01_EU_FN_FED01_201.wav',
#  'B_BAC01_MC_MN_SIM01_301.wav',
#  'I_DAK01_MC_FN_SIM01_303.wav',
#  'F_BRI01_MC_FI_SIM01_105.wav',
#  'I_MIN01_EU_FN_BEN01_106.wav',
#  'F_WHO01_MC_FI_SIM01_103.wav',
#  'I_DAK01_MC_FN_SIM01_103.wav',
#  'B_CAN01_EU_FN_GIA01_101.wav',
#  'F_BRI01_MC_FI_SIM01_104.wav',
#  'B_ANI01_MC_FN_SIM01_102.wav',
#  'I_CLE01_EU_FN_FER01_112.wav',
#  'I_CLE01_EU_FN_FER01_115.wav',
#  'F_DAK01_MC_FN_SIM01_303.wav',
#  'I_REG01_EU_FN_GIO01_201.wav',
#  'I_WHO01_MC_FI_SIM01_115.wav',
#  'I_NUL01_MC_MI_SIM01_304.wav',
#  'B_CAN01_EU_FN_GIA01_307.wav',
#  'I_NUL01_MC_MI_SIM01_203.wav',
#  'B_CAN01_EU_FN_GIA01_104.wav',
#  'F_WHO01_MC_FI_SIM01_301.wav',
#  'B_REG01_EU_FN_GIO01_101.wav',
#  'I_CAN01_EU_FN_GIA01_210.wav',
#  'I_DAK01_MC_FN_SIM01_109.wav',
#  'F_SPI01_EU_MN_NAI01_201.wav',
#  'F_DAK01_MC_FN_SIM01_304.wav',
#  'I_CAN01_EU_FN_GIA01_105.wav',
#  'I_DAK01_MC_FN_SIM01_111.wav',
#  'I_NUL01_MC_MI_SIM01_202.wav',
#  'F_MAG01_EU_FN_FED01_106.wav',
#  'I_BLE01_EU_FN_DEL01_304.wav',
#  'F_BRI01_MC_FI_SIM01_102.wav',
#  'B_NIG01_MC_MN_SIM01_102.wav',
#  'F_BAC01_MC_MN_SIM01_202.wav',
#  'B_TIG01_EU_FN_GIU01_201.wav',
#  'B_IND01_EU_FN_ELI01_202.wav',
#  'B_TIG01_EU_FN_GIU01_301.wav',
#  'I_WHO01_MC_FI_SIM01_112.wav',
#  'I_BLE01_EU_FN_DEL01_201.wav',
#  'I_DAK01_MC_FN_SIM01_304.wav',
#  'I_CAN01_EU_FN_GIA01_107.wav',
#  'I_BLE01_EU_FN_DEL01_308.wav',
#  'I_BLE01_EU_FN_DEL01_214.wav',
#  'I_BLE01_EU_FN_DEL01_105.wav',
#  'B_CAN01_EU_FN_GIA01_311.wav',
#  'B_SPI01_EU_MN_NAI01_102.wav',
#  'I_SPI01_EU_MN_NAI01_305.wav',
#  'I_NUL01_MC_MI_SIM01_201.wav',
#  'B_BAC01_MC_MN_SIM01_202.wav',
#  'I_DAK01_MC_FN_SIM01_116.wav',
#  'F_BRI01_MC_FI_SIM01_202.wav',
#  'I_BLE01_EU_FN_DEL01_216.wav',
#  'F_BAC01_MC_MN_SIM01_104.wav',
#  'I_SPI01_EU_MN_NAI01_202.wav',
#  'I_BLE01_EU_FN_DEL01_405.wav',
#  'B_MAG01_EU_FN_FED01_203.wav',
#  'I_MAT01_EU_FN_RIT01_203.wav',
#  'I_SPI01_EU_MN_NAI01_103.wav',
#  'B_CAN01_EU_FN_GIA01_304.wav',
#  'I_WHO01_MC_FI_SIM01_104.wav',
#  'B_NUL01_MC_MI_SIM01_302.wav',
#  'B_ANI01_MC_FN_SIM01_101.wav',
#  'I_CLE01_EU_FN_FER01_110.wav',
#  'I_BLE01_EU_FN_DEL01_404.wav',
#  'F_MAG01_EU_FN_FED01_202.wav',
#  'F_MIN01_EU_FN_BEN01_104.wav',
#  'I_DAK01_MC_FN_SIM01_316.wav',
#  'I_SPI01_EU_MN_NAI01_104.wav',
#  'I_BAC01_MC_MN_SIM01_102.wav',
#  'I_BLE01_EU_FN_DEL01_202.wav',
#  'I_MEG01_MC_FI_SIM01_101.wav',
#  'B_BRA01_MC_MN_SIM01_105.wav',
#  'B_CAN01_EU_FN_GIA01_210.wav',
#  'B_CAN01_EU_FN_GIA01_302.wav',
#  'F_BRA01_MC_MN_SIM01_301.wav',
#  'I_BLE01_EU_FN_DEL01_101.wav',
#  'I_CAN01_EU_FN_GIA01_304.wav',
#  'B_BRA01_MC_MN_SIM01_303.wav',
#  'I_SPI01_EU_MN_NAI01_105.wav',
#  'F_IND01_EU_FN_ELI01_102.wav',
#  'F_MAG01_EU_FN_FED01_305.wav',
#  'I_DAK01_MC_FN_SIM01_106.wav',
#  'B_CAN01_EU_FN_GIA01_309.wav',
#  'I_BLE01_EU_FN_DEL01_110.wav',
#  'F_MEG01_MC_FI_SIM01_302.wav',
#  'B_CAN01_EU_FN_GIA01_203.wav',
#  'B_CAN01_EU_FN_GIA01_310.wav',
#  'I_BLE01_EU_FN_DEL01_305.wav',
#  'B_MAG01_EU_FN_FED01_202.wav',
#  'B_CAN01_EU_FN_GIA01_206.wav',
#  'I_NIG01_MC_MN_SIM01_201.wav',
#  'I_ANI01_MC_FN_SIM01_102.wav',
#  'B_BRI01_MC_FI_SIM01_302.wav',
#  'B_CAN01_EU_FN_GIA01_209.wav',
#  'I_CLE01_EU_FN_FER01_109.wav',
#  'I_CLE01_EU_FN_FER01_105.wav',
#  'I_MAT01_EU_FN_RIT01_205.wav',
#  'I_CLE01_EU_FN_FER01_120.wav',
#  'I_WHO01_MC_FI_SIM01_111.wav',
#  'B_IND01_EU_FN_ELI01_303.wav',
#  'I_CLE01_EU_FN_FER01_106.wav',
#  'I_CLE01_EU_FN_FER01_111.wav',
#  'B_CAN01_EU_FN_GIA01_205.wav',
#  'I_BLE01_EU_FN_DEL01_306.wav',
#  'I_BLE01_EU_FN_DEL01_309.wav',
#  'B_ANI01_MC_FN_SIM01_302.wav',
#  'B_WHO01_MC_FI_SIM01_102.wav',
#  'I_CAN01_EU_FN_GIA01_106.wav',
#  'I_MAT01_EU_FN_RIT01_202.wav',
#  'F_SPI01_EU_MN_NAI01_104.wav',
#  'I_MEG01_MC_FI_SIM01_302.wav',
#  'I_DAK01_MC_FN_SIM01_313.wav',
#  'I_DAK01_MC_FN_SIM01_301.wav',
#  'I_SPI01_EU_MN_NAI01_101.wav',
#  'I_CLE01_EU_FN_FER01_102.wav',
#  'I_DAK01_MC_FN_SIM01_314.wav',
#  'B_NUL01_MC_MI_SIM01_301.wav',
#  'F_BAC01_MC_MN_SIM01_302.wav',
#  'F_SPI01_EU_MN_NAI01_102.wav',
#  'I_MIN01_EU_FN_BEN01_102.wav',
#  'F_BAC01_MC_MN_SIM01_201.wav',
#  'F_BAC01_MC_MN_SIM01_303.wav',
#  'B_MAT01_EU_FN_RIT01_202.wav',
#  'I_DAK01_MC_FN_SIM01_112.wav',
#  'F_LEO01_EU_MI_RIT01_102.wav',
#  'B_DAK01_MC_FN_SIM01_303.wav',
#  'I_BLE01_EU_FN_DEL01_307.wav',
#  'F_MAT01_EU_FN_RIT01_302.wav',
#  'I_DAK01_MC_FN_SIM01_102.wav',
#  'F_IND01_EU_FN_ELI01_202.wav',
#  'I_MIN01_EU_FN_BEN01_105.wav',
#  'F_WHO01_MC_FI_SIM01_303.wav',
#  'I_BLE01_EU_FN_DEL01_218.wav',
#  'I_CAN01_EU_FN_GIA01_202.wav',
#  'B_CAN01_EU_FN_GIA01_308.wav',
#  'I_BAC01_MC_MN_SIM01_303.wav',
#  'F_MEG01_MC_FI_SIM01_301.wav',
#  'I_DAK01_MC_FN_SIM01_306.wav',
#  'B_DAK01_MC_FN_SIM01_302.wav',
#  'I_SPI01_EU_MN_NAI01_102.wav',
#  'B_MAT01_EU_FN_RIT01_203.wav',
#  'B_BRA01_MC_MN_SIM01_106.wav',
#  'B_BAC01_MC_MN_SIM01_103.wav',
#  'I_CLE01_EU_FN_FER01_113.wav',
#  'I_BRA01_MC_MN_SIM01_101.wav',
#  'I_NUL01_MC_MI_SIM01_301.wav',
#  'I_BLE01_EU_FN_DEL01_210.wav',
#  'I_CAN01_EU_FN_GIA01_201.wav',
#  'B_BAC01_MC_MN_SIM01_102.wav',
#  'B_BRI01_MC_FI_SIM01_101.wav',
#  'I_SPI01_EU_MN_NAI01_303.wav',
#  'I_DAK01_MC_FN_SIM01_308.wav',
#  'I_CAN01_EU_FN_GIA01_103.wav',
#  'I_WHO01_MC_FI_SIM01_108.wav',
#  'I_BLE01_EU_FN_DEL01_401.wav',
#  'I_DAK01_MC_FN_SIM01_107.wav',
#  'B_MAT01_EU_FN_RIT01_205.wav',
#  'I_MAT01_EU_FN_RIT01_209.wav']

# %%
lista = [i.removesuffix(".wav").split("_")[:-1] for i in os.listdir(dataset_path)]
num_1 = [i.removesuffix(".wav").split("_")[-1][0] for i in os.listdir(dataset_path)]
num_2 = [i.removesuffix(".wav").split("_")[-1][1:] for i in os.listdir(dataset_path)]

# %%
dataf = {"Path_audios":os.listdir(dataset_path),
        "Necesidad":[i[0] for i in lista],
        "ID_Gato": [i[1] for i in lista],
        "Raza":[i[2] for i in lista],
        "Sexo":[i[3] for i in lista],
        "ID_Dueño":[i[4] for i in lista],
        "Recording_Session":[j for j in num_1],
        "Vocalization_Counter":[j for j in num_2]}

# %%
df = pd.DataFrame(dataf)

# %%
df = df.sort_values("ID_Gato").reset_index(drop=True)

# %%
df
# Out:
#                      Path_audios Necesidad ID_Gato Raza Sexo ID_Dueño  \
# 0    B_ANI01_MC_FN_SIM01_303.wav         B   ANI01   MC   FN    SIM01
# 1    I_ANI01_MC_FN_SIM01_104.wav         I   ANI01   MC   FN    SIM01
# 2    B_ANI01_MC_FN_SIM01_101.wav         B   ANI01   MC   FN    SIM01
# 3    B_ANI01_MC_FN_SIM01_103.wav         B   ANI01   MC   FN    SIM01
# 4    B_ANI01_MC_FN_SIM01_302.wav         B   ANI01   MC   FN    SIM01
# ..                           ...       ...     ...  ...  ...      ...
# 435  F_WHO01_MC_FI_SIM01_307.wav         F   WHO01   MC   FI    SIM01
# 436  I_WHO01_MC_FI_SIM01_103.wav         I   WHO01   MC   FI    SIM01
# 437  B_WHO01_MC_FI_SIM01_202.wav         B   WHO01   MC   FI    SIM01
# 438  B_WHO01_MC_FI_SIM01_302.wav         B   WHO01   MC   FI    SIM01
# 439  B_WHO01_MC_FI_SIM01_301.wav         B   WHO01   MC   FI    SIM01
#
#     Recording_Session Vocalization_Counter
# 0                   3                   03
# 1                   1                   04
# 2                   1                   01
# 3                   1                   03
# 4                   3                   02
# ..                ...                  ...
# 435                 3                   07
# 436                 1                   03
# 437                 2                   02
# 438                 3                   02
# 439                 3                   01
#
# [440 rows x 8 columns]

# %%
ruta_primer_audio = os.path.join(dataset_path,df.iloc[0]["Path_audios"])
ruta_primer_audio
# Out:
# '/home/fll_data_bata/code/Franloplam/DB Gatos/dataset/dataset/B_ANI01_MC_FN_SIM01_303.wav'

# %%
audio, sr = librosa.load(ruta_primer_audio)
spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr)

# %%
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(spectrogram, ref=np.max), y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma_Audio_1');

# %%
spectrogram.shape
# Out:
# (128, 83)

# %%
ruta_segundo_audio = os.path.join(dataset_path,df.iloc[22]["Path_audios"])
print(ruta_segundo_audio)
audio, sr = librosa.load(ruta_segundo_audio)
spectrogram2 = librosa.feature.melspectrogram(y=audio, sr=sr)
spectrogram2.shape
# Out:
# /home/fll_data_bata/code/Franloplam/DB Gatos/dataset/dataset/I_BAC01_MC_MN_SIM10_102.wav
# (128, 79)

# %%
ruta_tercer_audio = os.path.join(dataset_path,df.iloc[435]["Path_audios"])
print(ruta_tercer_audio)
audio, sr = librosa.load(ruta_tercer_audio)
spectrogram3 = librosa.feature.melspectrogram(y=audio, sr=sr)
spectrogram3.shape
# Out:
# /home/fll_data_bata/code/Franloplam/DB Gatos/dataset/dataset/F_WHO01_MC_FI_SIM01_307.wav
# (128, 62)

# %% [markdown]
# ----------

# %%
spectrogram
# Out:
# array([[4.16185139e-05, 7.95877131e-05, 3.84055056e-05, ...,
#         5.46959418e-05, 4.84995253e-05, 6.33112577e-05],
#        [3.92203583e-05, 5.72046119e-05, 8.83508474e-05, ...,
#         1.09453511e-04, 8.36168256e-05, 6.67213244e-05],
#        [1.19871765e-05, 4.37884119e-05, 1.50181586e-04, ...,
#         1.52963723e-04, 6.87962238e-05, 4.86089048e-05],
#        ...,
#        [1.61678351e-08, 4.01778966e-09, 1.08938063e-18, ...,
#         1.62168281e-19, 1.04963930e-13, 3.10998796e-11],
#        [1.57155586e-08, 3.90522992e-09, 8.23778160e-19, ...,
#         2.22679580e-19, 1.03366575e-13, 3.06233268e-11],
#        [1.54388555e-08, 3.83641163e-09, 1.01304468e-18, ...,
#         1.65111558e-19, 1.02330931e-13, 3.03157707e-11]], dtype=float32)

# %%
altura_nueva= 128
ancho_nuevo=128

# %%
spectrogram_redimension = ndimage.zoom(spectrogram, (altura_nueva / spectrogram.shape[0], ancho_nuevo / spectrogram.shape[1]))

# %%
spectrogram_redimension.shape
# Out:
# (128, 128)

# %%
fig,ax = plt.subplots(1,2,figsize=(15,6))

im1 = ax[0].imshow(librosa.power_to_db(spectrogram, ref=np.max), aspect='auto', origin='lower', cmap='viridis')
ax[0].set_title('Espectrograma original')
fig.colorbar(im1, ax=ax[0], format='%+2.0f dB')

im2 = ax[1].imshow(librosa.power_to_db(spectrogram_redimension, ref=np.max), aspect='auto', origin='lower', cmap='viridis')
ax[1].set_title('Espectrograma redimensionado')
fig.colorbar(im2, ax=ax[1], format='%+2.0f dB');

# %%
dataset_path
# Out:
# '/home/fll_data_bata/code/Franloplam/DB Gatos/dataset/dataset'

# %%
del df["Path_audios"]

# %%
df = df.rename(columns={"Resized_Audios":"Path_Audios"})

# %%
df
# Out:
#     Necesidad ID_Gato Raza Sexo ID_Dueño Recording_Session  \
# 0           B   ANI01   MC   FN    SIM01                 3
# 1           I   ANI01   MC   FN    SIM01                 1
# 2           B   ANI01   MC   FN    SIM01                 1
# 3           B   ANI01   MC   FN    SIM01                 1
# 4           B   ANI01   MC   FN    SIM01                 3
# ..        ...     ...  ...  ...      ...               ...
# 435         F   WHO01   MC   FI    SIM01                 3
# 436         I   WHO01   MC   FI    SIM01                 1
# 437         B   WHO01   MC   FI    SIM01                 2
# 438         B   WHO01   MC   FI    SIM01                 3
# 439         B   WHO01   MC   FI    SIM01                 3
#
#     Vocalization_Counter                                        Path_Audios
# 0                     03  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 1                     04  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 2                     01  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 3                     03  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 4                     02  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# ..                   ...                                                ...
# 435                   07  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 436                   03  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 437                   02  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 438                   02  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
# 439                   01  /home/fll_data_bata/code/Franloplam/DB Gatos/d...
#
# [440 rows x 8 columns]

# %%
df.value_counts("Necesidad")
# Out:
# Necesidad
# I    221
# B    127
# F     92
# dtype: int64
